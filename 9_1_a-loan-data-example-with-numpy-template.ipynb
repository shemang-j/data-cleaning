# %% [markdown]
# ## Importing the Packages

# %%
import numpy as np

# %%
np.set_printoptions(suppress = True , precision = 2, linewidth = 100)

# %% [markdown]
# ## Importing the Data

# %%
raw_data_np =np.genfromtxt("C:/Users/DELL E6430/Desktop/data science/365 data science/PROGRAMMING FOR DATA SCIENCE/data processing with numpys/9. a loan data pratical with numpy/loan-data.csv",
             delimiter = ';',
             skip_header = 1,
             autostrip = True)
raw_data_np
# Out:
# array([[48010226.  ,         nan,    35000.  , ...,         nan,         nan,     9452.96],
#        [57693261.  ,         nan,    30000.  , ...,         nan,         nan,     4679.7 ],
#        [59432726.  ,         nan,    15000.  , ...,         nan,         nan,     1969.83],
#        ...,
#        [50415990.  ,         nan,    10000.  , ...,         nan,         nan,     2185.64],
#        [46154151.  ,         nan,         nan, ...,         nan,         nan,     3199.4 ],
#        [66055249.  ,         nan,    10000.  , ...,         nan,         nan,      301.9 ]])

# %% [markdown]
# ## Checking for Incomplete Data

# %%
np.isnan(raw_data_np).sum()
# Out:
# 88005

# %%
temporary_fill = np.nanmax(raw_data_np).round(2) + 1
temporary_mean = np.nanmean(raw_data_np, axis = 0)
# Out:
# <ipython-input-82-6ef7ea16e215>:2: RuntimeWarning: Mean of empty slice
#   temporary_mean = np.nanmean(raw_data_np, axis = 0)

# %%
temporary_mean
# Out:
# array([54015809.19,         nan,    15273.46,         nan,    15311.04,         nan,       16.62,
#             440.92,         nan,         nan,         nan,         nan,         nan,     3143.85])

# %%
temporary_stat = np.array([np.nanmin(raw_data_np, axis = 0),
                         np.nanmean(raw_data_np, axis = 0),
                         np.nanmax(raw_data_np, axis = 0)])
# Out:
# <ipython-input-84-84ad614e1a3f>:1: RuntimeWarning: All-NaN slice encountered
#   temporary_stat = np.array([np.nanmin(raw_data_np, axis = 0),
# <ipython-input-84-84ad614e1a3f>:2: RuntimeWarning: Mean of empty slice
#   np.nanmean(raw_data_np, axis = 0),
# <ipython-input-84-84ad614e1a3f>:3: RuntimeWarning: All-NaN slice encountered
#   np.nanmax(raw_data_np, axis = 0)])

# %%
temporary_stat
# Out:
# array([[  373332.  ,         nan,     1000.  ,         nan,     1000.  ,         nan,        6.  ,
#               31.42,         nan,         nan,         nan,         nan,         nan,        0.  ],
#        [54015809.19,         nan,    15273.46,         nan,    15311.04,         nan,       16.62,
#              440.92,         nan,         nan,         nan,         nan,         nan,     3143.85],
#        [68616519.  ,         nan,    35000.  ,         nan,    35000.  ,         nan,       28.99,
#             1372.97,         nan,         nan,         nan,         nan,         nan,    41913.62]])

# %% [markdown]
# ## Splitting the Dataset

# %% [markdown]
# ### Splitting the Columns

# %%
column_strings = np.argwhere(np.isnan(temporary_mean)).squeeze()
column_strings
# Out:
# array([ 1,  3,  5,  8,  9, 10, 11, 12], dtype=int64)

# %%
column_numeric = np.argwhere(np.isnan(temporary_mean) == False).squeeze()
column_numeric
# Out:
# array([ 0,  2,  4,  6,  7, 13], dtype=int64)

# %% [markdown]
# ### Re-importing the Dataset

# %%
loan_data_strings =np.genfromtxt("C:/Users/DELL E6430/Desktop/data science/365 data science/PROGRAMMING FOR DATA SCIENCE/data processing with numpys/9. a loan data pratical with numpy/loan-data.csv",
                                delimiter = ';',
                                skip_header = 1,
                                autostrip = True,
                                usecols = column_strings,
                                dtype = 'str')
loan_data_strings
# Out:
# array([['May-15', 'Current', '36 months', ..., 'Verified',
#         'https://www.lendingclub.com/browse/loanDetail.action?loan_id=48010226', 'CA'],
#        ['', 'Current', '36 months', ..., 'Source Verified',
#         'https://www.lendingclub.com/browse/loanDetail.action?loan_id=57693261', 'NY'],
#        ['Sep-15', 'Current', '36 months', ..., 'Verified',
#         'https://www.lendingclub.com/browse/loanDetail.action?loan_id=59432726', 'PA'],
#        ...,
#        ['Jun-15', 'Current', '36 months', ..., 'Source Verified',
#         'https://www.lendingclub.com/browse/loanDetail.action?loan_id=50415990', 'CA'],
#        ['Apr-15', 'Current', '36 months', ..., 'Source Verified',
#         'https://www.lendingclub.com/browse/loanDetail.action?loan_id=46154151', 'OH'],
#        ['Dec-15', 'Current', '36 months', ..., '',
#         'https://www.lendingclub.com/browse/loanDetail.action?loan_id=66055249', 'IL']],
#       dtype='<U69')

# %%
loan_data_numeric =np.genfromtxt("C:/Users/DELL E6430/Desktop/data science/365 data science/PROGRAMMING FOR DATA SCIENCE/data processing with numpys/9. a loan data pratical with numpy/loan-data.csv",
                                delimiter = ';',
                                skip_header = 1,
                                autostrip = True,
                                usecols = column_numeric,
                                filling_values = temporary_fill)
loan_data_numeric
# Out:
# array([[48010226.  ,    35000.  ,    35000.  ,       13.33,     1184.86,     9452.96],
#        [57693261.  ,    30000.  ,    30000.  , 68616520.  ,      938.57,     4679.7 ],
#        [59432726.  ,    15000.  ,    15000.  , 68616520.  ,      494.86,     1969.83],
#        ...,
#        [50415990.  ,    10000.  ,    10000.  , 68616520.  , 68616520.  ,     2185.64],
#        [46154151.  , 68616520.  ,    10000.  ,       16.55,      354.3 ,     3199.4 ],
#        [66055249.  ,    10000.  ,    10000.  , 68616520.  ,      309.97,      301.9 ]])

# %% [markdown]
# ### The Names of the Columns

# %%
header_full =np.genfromtxt("C:/Users/DELL E6430/Desktop/data science/365 data science/PROGRAMMING FOR DATA SCIENCE/data processing with numpys/9. a loan data pratical with numpy/loan-data.csv",
                                delimiter = ';',
                                skip_footer= raw_data_np.shape[0],
                                autostrip = True,
                                dtype = 'str')
header_full
# Out:
# array(['id', 'issue_d', 'loan_amnt', 'loan_status', 'funded_amnt', 'term', 'int_rate',
#        'installment', 'grade', 'sub_grade', 'verification_status', 'url', 'addr_state',
#        'total_pymnt'], dtype='<U19')

# %%
header_numeric, header_strings  = header_full[column_numeric], header_full[column_strings]

# %%
header_numeric
# Out:
# array(['id', 'loan_amnt', 'funded_amnt', 'int_rate', 'installment', 'total_pymnt'], dtype='<U19')

# %%
header_strings
# Out:
# array(['issue_d', 'loan_status', 'term', 'grade', 'sub_grade', 'verification_status', 'url',
#        'addr_state'], dtype='<U19')

# %% [markdown]
# ## Creating Checkpoints:

# %%
def checkpoint(file_name, checkpoint_header, checkpoint_data):
    np.savez(file_name, header = checkpoint_header, data = checkpoint_data)
    checkpoint_variable = np.load(file_name + ".npz")
    return(checkpoint_variable)

# %%
checkpoint_test = checkpoint("checkpoint-test", header_strings, loan_data_strings)

# %%
checkpoint_test['header']
# Out:
# array(['issue_d', 'loan_status', 'term', 'grade', 'sub_grade', 'verification_status', 'url',
#        'addr_state'], dtype='<U19')

# %%
checkpoint_test["data"]
# Out:
# array([['May-15', 'Current', '36 months', ..., 'Verified',
#         'https://www.lendingclub.com/browse/loanDetail.action?loan_id=48010226', 'CA'],
#        ['', 'Current', '36 months', ..., 'Source Verified',
#         'https://www.lendingclub.com/browse/loanDetail.action?loan_id=57693261', 'NY'],
#        ['Sep-15', 'Current', '36 months', ..., 'Verified',
#         'https://www.lendingclub.com/browse/loanDetail.action?loan_id=59432726', 'PA'],
#        ...,
#        ['Jun-15', 'Current', '36 months', ..., 'Source Verified',
#         'https://www.lendingclub.com/browse/loanDetail.action?loan_id=50415990', 'CA'],
#        ['Apr-15', 'Current', '36 months', ..., 'Source Verified',
#         'https://www.lendingclub.com/browse/loanDetail.action?loan_id=46154151', 'OH'],
#        ['Dec-15', 'Current', '36 months', ..., '',
#         'https://www.lendingclub.com/browse/loanDetail.action?loan_id=66055249', 'IL']],
#       dtype='<U69')

# %% [markdown]
# ## Manipulating String Columns

# %%
header_strings
# Out:
# array(['issue_d', 'loan_status', 'term', 'grade', 'sub_grade', 'verification_status', 'url',
#        'addr_state'], dtype='<U19')

# %%
header_strings[0] = "issue_date"

# %%
loan_data_strings
# Out:
# array([['May-15', 'Current', '36 months', ..., 'Verified',
#         'https://www.lendingclub.com/browse/loanDetail.action?loan_id=48010226', 'CA'],
#        ['', 'Current', '36 months', ..., 'Source Verified',
#         'https://www.lendingclub.com/browse/loanDetail.action?loan_id=57693261', 'NY'],
#        ['Sep-15', 'Current', '36 months', ..., 'Verified',
#         'https://www.lendingclub.com/browse/loanDetail.action?loan_id=59432726', 'PA'],
#        ...,
#        ['Jun-15', 'Current', '36 months', ..., 'Source Verified',
#         'https://www.lendingclub.com/browse/loanDetail.action?loan_id=50415990', 'CA'],
#        ['Apr-15', 'Current', '36 months', ..., 'Source Verified',
#         'https://www.lendingclub.com/browse/loanDetail.action?loan_id=46154151', 'OH'],
#        ['Dec-15', 'Current', '36 months', ..., '',
#         'https://www.lendingclub.com/browse/loanDetail.action?loan_id=66055249', 'IL']],
#       dtype='<U69')

# %% [markdown]
# ### Issue Date

# %%
np.unique(loan_data_strings[:,0])
# Out:
# array(['', 'Apr-15', 'Aug-15', 'Dec-15', 'Feb-15', 'Jan-15', 'Jul-15', 'Jun-15', 'Mar-15',
#        'May-15', 'Nov-15', 'Oct-15', 'Sep-15'], dtype='<U69')

# %%
loan_data_strings[:,0] = np.chararray.strip(loan_data_strings[:,0], '-15')

# %%
np.unique(loan_data_strings[:,0])
# Out:
# array(['', 'Apr', 'Aug', 'Dec', 'Feb', 'Jan', 'Jul', 'Jun', 'Mar', 'May', 'Nov', 'Oct', 'Sep'],
#       dtype='<U69')

# %%
months = np.array(['', 'Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec'])

# %%
for i in range(13):
        loan_data_strings[:,0] = np.where(loan_data_strings[:,0] == months[i],
                                          i,
                                          loan_data_strings[:,0])

# %%
np.unique(loan_data_strings[:,0])
# Out:
# array(['0', '1', '10', '11', '12', '2', '3', '4', '5', '6', '7', '8', '9'], dtype='<U69')

# %% [markdown]
# ### Loan Status

# %% [markdown]
# ### Term

# %% [markdown]
# ### Grade and Subgrade

# %% [markdown]
# #### Filling Sub Grade

# %%
for i in np.unique(loan_data_strings[:,3])[1:]:
    loan_data_strings[:,4] = np.where((loan_data_strings[:,4] == '') & (loan_data_strings[:,3] == i),
                                      i + '5',
                                      loan_data_strings[:,4])

# %% [markdown]
# #### Removing Grade

# %% [markdown]
# #### Converting Sub Grade

# %%
keys = list(np.unique(loan_data_strings[:,3]))                         
values = list(range(1, np.unique(loan_data_strings[:,3]).shape[0] + 1)) 
dict_sub_grade = dict(zip(keys, values))

# %%
for i in np.unique(loan_data_strings[:,3]):
        loan_data_strings[:,3] = np.where(loan_data_strings[:,3] == i, 
                                          dict_sub_grade[i],
                                          loan_data_strings[:,3])

# %% [markdown]
# ### Verification Status

# %% [markdown]
# ### URL

# %% [markdown]
# ### State Address

# %%
states_west = np.array(['WA', 'OR','CA','NV','ID','MT', 'WY','UT','CO', 'AZ','NM','HI','AK'])
states_south = np.array(['TX','OK','AR','LA','MS','AL','TN','KY','FL','GA','SC','NC','VA','WV','MD','DE','DC'])
states_midwest = np.array(['ND','SD','NE','KS','MN','IA','MO','WI','IL','IN','MI','OH'])
states_east = np.array(['PA','NY','NJ','CT','MA','VT','NH','ME','RI'])

# %% [markdown]
# https://www2.census.gov/geo/pdfs/maps-data/maps/reference/us_regdiv.pdf

# %% [markdown]
# ## Converting to Numbers

# %% [markdown]
# ### Checkpoint 1: Strings

# %% [markdown]
# ## Manipulating Numeric Columns

# %% [markdown]
# ### Substitute "Filler" Values

# %% [markdown]
# #### ID

# %% [markdown]
# #### Temporary Stats

# %% [markdown]
# #### Funded Amount

# %%
loan_data_numeric[:,2] = np.where(loan_data_numeric[:,2] == temporary_fill, 
                                  temporary_stats[0, columns_numeric[2]],
                                  loan_data_numeric[:,2])
loan_data_numeric[:,2]

# %% [markdown]
# #### Loaned Amount, Interest Rate, Total Payment, Installment

# %% [markdown]
# ### Currency Change

# %% [markdown]
# #### The Exchange Rate

# %%
for i in range(1,13):
    exchange_rate = np.where(exchange_rate == i,
                             EUR_USD[i-1],
                             exchange_rate)

# %% [markdown]
# #### From USD to EUR

# %%
for i in columns_dollar:
    loan_data_numeric = np.hstack((loan_data_numeric, np.reshape(loan_data_numeric[:,i] / loan_data_numeric[:,6], (10000,1))))

# %% [markdown]
# #### Expanding the header

# %%
header_additional = np.array([column_name + '_EUR' for column_name in header_numeric[columns_dollar]])

# %%
columns_index_order = [0,1,7,2,8,3,4,9,5,10,6]

# %% [markdown]
# ### Interest Rate

# %% [markdown]
# ### Checkpoint 2: Numeric

# %%
checkpoint_numeric['header'], checkpoint_numeric['data']

# %% [markdown]
# ## Creating the "Complete" Dataset

# %% [markdown]
# ## Sorting the New Dataset

# %% [markdown]
# ## Storing the New Dataset
